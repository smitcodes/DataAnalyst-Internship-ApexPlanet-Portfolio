# %% [markdown]
# # Hypothesis Test

# %%
import pandas as pd
from scipy.stats import ttest_ind

# %% [markdown]
# ## Load dataset

# %%
df = pd.read_csv("superstore_cleaned.csv")

# %% [markdown]
# ## Extract profits

# %%
tech_profit = df[df['Category'] == 'Technology']['Profit']
furniture_profit = df[df['Category'] == 'Furniture']['Profit']

# %% [markdown]
# ## Perform t-test

# %%
t_stat, p_value = ttest_ind(tech_profit, furniture_profit)

print("T-Statistic:", t_stat)
print("P-Value:", p_value)
# Out:
# T-Statistic: 7.1232394903693965
# P-Value: 1.246076188584697e-12

# %% [markdown]
# ## Interpretation

# %%
alpha = 0.05

if p_value < alpha:
    print("Reject Null Hypothesis")
    print("Technology profit is significantly higher.")
else:
    print("Fail to Reject Null Hypothesis")
# Out:
# Reject Null Hypothesis
# Technology profit is significantly higher.
